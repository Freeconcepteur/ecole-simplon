# %%
import numpy as np
x = np.random.randint(1, 5, 10)
print(x)
y = np.array([2, 1, 4, 5, 8, 12, 18, 25, 96, 48])
print(y)

r = np.corrcoef(x, y)
r
# Out:
# [1 3 2 2 2 1 2 1 4 4]
# [ 2  1  4  5  8 12 18 25 96 48]
# array([[1.        , 0.67999853],
#        [0.67999853, 1.        ]])

# %%
r = np.corrcoef(x,y)
print(r)
# Out:
# [[1.         0.67999853]
#  [0.67999853 1.        ]]

# %% [markdown]
# ## Corrélation entre cos(x) et sin(x)

# %%
x = np.linspace(0, -300, 1000)
y_cos = np.cos(x)
y_sin = np.sin(x)

r = np.corrcoef(y_cos,y_sin)
print(r)
# Out:
# [[ 1.         -0.00326606]
#  [-0.00326606  1.        ]]

# %%
import matplotlib.pyplot as plt

x = np.random.normal(-100, 100, 50)
y = np.random.normal(-100, 100, 50)
z = np.random.normal(-100, 100, 50)

print(np.corrcoef([x,y,z]))

plt.plot(x)
plt.plot(y)
plt.plot(z)
# Out:
# [[ 1.         -0.18161055 -0.29979436]
#  [-0.18161055  1.         -0.002962  ]
#  [-0.29979436 -0.002962    1.        ]]
